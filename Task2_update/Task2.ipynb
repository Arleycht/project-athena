# %%
import os
import sys
from pathlib import Path

# %%
# Set up proper directory paths

project_path = Path().absolute().parent
src_path = project_path.joinpath("src")

# Ensure the paths are properly assigned
# If this assertion fails, change project_dir as needed to become the project directory
# If project_dir is correct, change the name in the assertion check
assert project_path.name == "project-athena", "Parent directory name assertion failed (check the path)"

# %%
# Add src_dir to module paths
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# %%
import time

import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
from attacks.attack import generate
from models.athena import ENSEMBLE_STRATEGY, Ensemble
from utils.data import subsampling
from utils.file import load_from_json, dump_to_json
from utils.metrics import error_rate, get_corrections
from utils.model import load_lenet, load_pool

# %%
# copied from tutorials/craft_adversarial_examples.py
def generate_ae(model, data, labels, attack_configs,
                eot=False,
                save=False, output_dir=None):
    """
    Generate adversarial examples
    :param model: WeakDefense. The targeted model.
    :param data: array. The benign samples to generate adversarial for.
    :param labels: array or list. The true labels.
    :param attack_configs: dictionary. Attacks and corresponding settings.
    :param save: boolean. True, if save the adversarial examples.
    :param output_dir: str or path. Location to save the adversarial examples.
        It cannot be None when save is True.
    :return:
    """
    img_rows, img_cols = data.shape[1], data.shape[2]
    num_attacks = attack_configs.get("num_attacks")
    data_loader = (data, labels)

    if len(labels.shape) > 1:
        labels = np.asarray([np.argmax(p) for p in labels])

    # generate attacks one by one
    for id in range(num_attacks):
        key = "configs{}".format(id)
        attack_args = attack_configs.get(key)
        
        description = attack_args['description']
        
        attack_args["eot"] = eot
        
        data_adv = generate(model=model,
                            data_loader=data_loader,
                            attack_args=attack_args)
        
        # predict the adversarial examples
        predictions = model.predict(data_adv)
        predictions = np.asarray([np.argmax(p) for p in predictions])

        err = error_rate(y_pred=predictions, y_true=labels)
        print(">>> error rate:", err)

        # plotting some examples
        num_plotting = min(data.shape[0], 2)
        for i in range(num_plotting):
            img = data_adv[i].reshape((img_rows, img_cols))
            plt.imshow(img, cmap='gray')
            title = '{}: {}->{}'.format(description,
                                        labels[i],
                                        predictions[i])
            plt.title(title)
            plt.savefig(project_path.joinpath(f"Task2_update/images/{description}-{i}-EOT_{'ON' if eot else 'OFF'}.png"))
            plt.show()
            plt.close()

        # save the adversarial example
        if save:
            if output_dir is None:
                raise ValueError("Cannot save images to a none path.")
            # save with a random name
            file = os.path.join(output_dir, f"{description}.npy")
            print("Save the adversarial examples to file [{}].".format(file))
            np.save(file, data_adv)

# %%
# Load data configs
file = project_path.joinpath("Task2_update/configs/data-mnist.json")
data_configs = load_from_json(file)

trans_configs = load_from_json(project_path.joinpath("Task2_update/configs/athena-mnist.json"))
model_configs = load_from_json(project_path.joinpath("Task2_update/configs/model-mnist.json"))

# In the context of the white-box threat model,
# we use the ensemble as adversary's target model.
pool, _ = load_pool(trans_configs=trans_configs,
                    model_configs=model_configs,
                    active_list=True,
                    wrap=True)

# create an AVEP ensemble from the WD pool
wds = list(pool.values())
target = Ensemble(classifiers=wds, strategy=ENSEMBLE_STRATEGY.AVEP.value)

# load the benign samples
data_file = project_path.joinpath(data_configs['dir'], data_configs.get('bs_file'))
data_bs = np.load(data_file)
# load the corresponding true labels
label_file = project_path.joinpath(data_configs['dir'], data_configs.get('label_file'))
labels = np.load(label_file)


output_path = project_path.joinpath("Task2_update/data/adversary_examples")
# Out:
# >>> Loading model [../models/cnn/model-mnist-cnn-rotate90.h5]...
# >>> Loading model [../models/cnn/model-mnist-cnn-shift_left.h5]...
# >>> Loading model [../models/cnn/model-mnist-cnn-flip_horizontal.h5]...
# >>> Loading model [../models/cnn/model-mnist-cnn-affine_vertical_compress.h5]...
# >>> Loading model [../models/cnn/model-mnist-cnn-morph_erosion.h5]...
# >>> Loaded 5 models.

# %%
# EOT OFF
attack_configs = load_from_json(project_path.joinpath("Task2_update/configs/attack-wb-mnist.json"))
generate_ae(model=target, data=data_bs,labels=labels, attack_configs=attack_configs,
            save=True, output_dir=output_path)
# Out:
# >>> Generating PGD_eps0.08(EOT:OFF) examples.
# >>> error rate: 0.014
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\PGD_eps0.08.npy].
# >>> Generating PGD_eps0.12(EOT:OFF) examples.
# >>> error rate: 0.02
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\PGD_eps0.12.npy].
# >>> Generating PGD_eps0.15(EOT:OFF) examples.
# >>> error rate: 0.03
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\PGD_eps0.15.npy].
# >>> Generating PGD_eps0.17(EOT:OFF) examples.
# >>> error rate: 0.04
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\PGD_eps0.17.npy].
# >>> Generating PGD_eps0.2(EOT:OFF) examples.
# >>> error rate: 0.048
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\PGD_eps0.2.npy].
# >>> Generating FGSM_eps0.1(EOT:OFF) examples.
# >>> error rate: 0.014
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\FGSM_eps0.1.npy].
# >>> Generating FGSM_eps0.15(EOT:OFF) examples.
# >>> error rate: 0.024
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\FGSM_eps0.15.npy].
# >>> Generating FGSM_eps0.2(EOT:OFF) examples.
# >>> error rate: 0.064
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\FGSM_eps0.2.npy].
# >>> Generating FGSM_eps0.23(EOT:OFF) examples.
# >>> error rate: 0.12
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\FGSM_eps0.23.npy].
# >>> Generating FGSM_eps0.25(EOT:OFF) examples.
# >>> error rate: 0.17
# Save the adversarial examples to file [C:\Users\covin\PycharmProjects\585 Project\project-athena\Task2_update\data\adversary_examples\FGSM_eps0.25.npy].

# %%
# EOT ON
attack_configs = load_from_json(project_path.joinpath("Task2_update/configs/attack-wb-mnist-EOT_ON.json"))

# Adaptive approach (with EOT)
# Compute the loss expectation over specific distribution.
# For an ensemble target, averaging the EOT of WDs'.
# let save=True and specify an output folder to save the generated AEs
generate_ae(model=target, data=data_bs, labels=labels, eot=True, attack_configs=attack_configs, save=True, output_dir=output_path)
# Out:
# >>> Generating PGD_eps0.05EOT_ON(EOT:ON) examples.
# >>> error rate: 0.012
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\PGD_eps0.05EOT_ON.npy].
# >>> Generating PGD_eps0.2EOT_ON(EOT:ON) examples.
# >>> error rate: 0.038
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\PGD_eps0.2EOT_ON.npy].
# >>> Generating PGD_eps0.5EOT_ON(EOT:ON) examples.
# >>> error rate: 0.754
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\PGD_eps0.5EOT_ON.npy].
# >>> Generating PGD_eps0.7EOT_ON(EOT:ON) examples.
# >>> error rate: 0.948
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\PGD_eps0.7EOT_ON.npy].
# >>> Generating PGD_eps0.1EOT_ON(EOT:ON) examples.
# >>> error rate: 0.018
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\PGD_eps0.1EOT_ON.npy].
# >>> Generating FGSM_eps0.01EOT_ON(EOT:ON) examples.
# >>> error rate: 0.01
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\FGSM_eps0.01EOT_ON.npy].
# >>> Generating FGSM_eps0.05EOT_ON(EOT:ON) examples.
# >>> error rate: 0.008
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\FGSM_eps0.05EOT_ON.npy].
# >>> Generating FGSM_eps0.1EOT_ON(EOT:ON) examples.
# >>> error rate: 0.022
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\FGSM_eps0.1EOT_ON.npy].
# >>> Generating FGSM_eps0.2EOT_ON(EOT:ON) examples.
# >>> error rate: 0.05
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\FGSM_eps0.2EOT_ON.npy].
# >>> Generating FGSM_eps0.5EOT_ON(EOT:ON) examples.
# >>> error rate: 0.828
# Save the adversarial examples to file [D:\GitHub\project-athena\Task2\data\FGSM_eps0.5EOT_ON.npy].

# %% [markdown]
# # Evaluating the generated adverserial example on the vanilla Athena.

# %%
file = project_path.joinpath("Task2/configs/data-mnist.json")
data_configs = load_from_json(file)

img_rows, img_cols = data_bs.shape[1], data_bs.shape[2]

pred_bs = target.predict(data_bs)
corrections = get_corrections(y_pred=pred_bs, y_true=labels)

results = {}

ae_files = data_configs.get('task2_aes')

for file in ae_files:
    results[file] = {}
    ae_file = project_path.joinpath(data_configs['dir'], file)
    x_adversarial = np.load(ae_file)
    print(f">>> Running evaluations on [{ae_file}]")
    pred = target.predict(x_adversarial)
    err = error_rate(y_pred=pred, y_true=labels, correct_on_bs=corrections)
    print(f">>> Error Rate of {file}: [{err}]")
    results[file] = err
    
result_file = project_path.joinpath("Task2/results/ae_evaluation_results.json")
dump_to_json(results, result_file)
print(f">>> Evaluations on all ae_files dumped to [{result_file}]")
# Out:
# H:\Programs\Anaconda\envs\env_name\lib\site-packages\skimage\transform\radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])
# H:\Programs\Anaconda\envs\env_name\lib\site-packages\skimage\transform\radon_transform.py:91: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn('Radon transform: image must be zero outside the '
# H:\GitHub\project-athena\src\models\image_processor.py:861: FutureWarning: 'filter' is a deprecated argument name for `iradon`. It will be removed in version 0.19. Please use 'filter_name' instead.
#   interpolation=interpolation, circle=circle))
# H:\GitHub\project-athena\src\models\image_processor.py:73: UserWarning: Possible precision loss converting image of type float32 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   return _segment_trans(X, trans_args)
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-FGSM_0.5.npy]
# >>> Error Rate of task2-FGSM_0.5.npy: [0.8704453441295547]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-FGSM_eps0.1.npy]
# >>> Error Rate of task2-FGSM_eps0.1.npy: [0.010121457489878543]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-FGSM_eps0.01.npy]
# >>> Error Rate of task2-FGSM_eps0.01.npy: [0.0020242914979757085]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-FGSM_eps0.2.npy]
# >>> Error Rate of task2-FGSM_eps0.2.npy: [0.058704453441295545]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-FGSM_eps0.05.npy]
# >>> Error Rate of task2-FGSM_eps0.05.npy: [0.004048582995951417]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-PGD_eps0.1.npy]
# >>> Error Rate of task2-PGD_eps0.1.npy: [0.022267206477732792]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-PGD_eps0.2.npy]
# >>> Error Rate of task2-PGD_eps0.2.npy: [0.12753036437246965]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-PGD_eps0.5.npy]
# >>> Error Rate of task2-PGD_eps0.5.npy: [0.8866396761133604]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-PGD_eps0.05.npy]
# >>> Error Rate of task2-PGD_eps0.05.npy: [0.006072874493927126]
# >>> Running evaluations on [H:\GitHub\project-athena\Task2\data\task2-PGD_eps0.7.npy]
# >>> Error Rate of task2-PGD_eps0.7.npy: [0.9655870445344129]
# >>> Evaluations on all ae_files dumped to [H:\GitHub\project-athena\Task2\results\ae_evaluation_results.json]

# %%
# Running the baseline adversarial examples
file = project_path.joinpath("Task2/configs/data-mnist.json")
data_configs = load_from_json(file)

# load the benign samples
data_file = project_path.joinpath(data_configs['bl_dir'], data_configs.get('all_bs_file'))
data_bs = np.load(data_file)
# load the corresponding true labels
label_file = project_path.joinpath(data_configs['bl_dir'], data_configs.get('all_label_file'))
labels = np.load(label_file)

img_rows, img_cols = data_bs.shape[1], data_bs.shape[2]

pred_bs = target.predict(data_bs)
corrections = get_corrections(y_pred=pred_bs, y_true=labels)

results = {}

ae_files = data_configs.get('ae_files')

for file in ae_files:
    results[file] = {}
    ae_file = project_path.joinpath(data_configs['bl_dir'], file)
    x_adversarial = np.load(ae_file)
    print(f">>> Running evaluations on [{ae_file}]")
    pred = target.predict(x_adversarial)
    err = error_rate(y_pred=pred, y_true=labels, correct_on_bs=corrections)
    print(f">>> Error Rate of {file}: [{err}]")
    results[file] = err
    
result_file = project_path.joinpath("Task2/results/baseline_ae_evaluation_results.json")
dump_to_json(results, result_file)
print(f">>> Evaluations on all ae_files dumped to [{result_file}]")
# Out:
# H:\Programs\Anaconda\envs\env_name\lib\site-packages\skimage\transform\radon_transform.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords = np.array(np.ogrid[:image.shape[0], :image.shape[1]])
# H:\Programs\Anaconda\envs\env_name\lib\site-packages\skimage\transform\radon_transform.py:91: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn('Radon transform: image must be zero outside the '
# H:\GitHub\project-athena\src\models\image_processor.py:861: FutureWarning: 'filter' is a deprecated argument name for `iradon`. It will be removed in version 0.19. Please use 'filter_name' instead.
#   interpolation=interpolation, circle=circle))
# H:\GitHub\project-athena\src\models\image_processor.py:73: UserWarning: Possible precision loss converting image of type float32 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   return _segment_trans(X, trans_args)
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-fgsm_eps0.1.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-fgsm_eps0.1.npy: [0.011493094061901401]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-fgsm_eps0.15.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-fgsm_eps0.15.npy: [0.030345800988002825]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-fgsm_eps0.2.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-fgsm_eps0.2.npy: [0.07561246093356185]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-fgsm_eps0.25.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-fgsm_eps0.25.npy: [0.19628994858352655]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-fgsm_eps0.3.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-fgsm_eps0.3.npy: [0.39419296300030243]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ord2_eps0.75.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ord2_eps0.75.npy: [0.01058574453069866]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ord2_eps0.85.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ord2_eps0.85.npy: [0.012803710051416473]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ord2_eps1.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ord2_eps1.npy: [0.018651073696945256]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ord2_eps1.1.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ord2_eps1.1.npy: [0.02318782135295897]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ord2_eps1.2.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ord2_eps1.2.npy: [0.028732735154753504]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ordinf_eps0.075.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ordinf_eps0.075.npy: [0.008065329166246598]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ordinf_eps0.082.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ordinf_eps0.082.npy: [0.01018247807238633]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ordinf_eps0.09.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ordinf_eps0.09.npy: [0.012097993749369896]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ordinf_eps0.1.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ordinf_eps0.1.npy: [0.014618409113821958]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-bim_ordinf_eps0.12.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-bim_ordinf_eps0.12.npy: [0.02449843734247404]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-cw_l2_lr0.0098.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-cw_l2_lr0.0098.npy: [0.0023187821352958966]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-cw_l2_lr0.01.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-cw_l2_lr0.01.npy: [0.0022179655207178145]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-cw_l2_lr0.012.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-cw_l2_lr0.012.npy: [0.0020163322915616494]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-cw_l2_lr0.015.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-cw_l2_lr0.015.npy: [0.0025204153644520617]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-cw_l2_lr0.018.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-cw_l2_lr0.018.npy: [0.0020163322915616494]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-deepfool_l2_overshoot3.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-deepfool_l2_overshoot3.npy: [0.013307793124306886]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-deepfool_l2_overshoot5.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-deepfool_l2_overshoot5.npy: [0.07077326343381389]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-deepfool_l2_overshoot8.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-deepfool_l2_overshoot8.npy: [0.2669623954027624]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-deepfool_l2_overshoot16.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-deepfool_l2_overshoot16.npy: [0.5767718520012098]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-deepfool_l2_overshoot50.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-deepfool_l2_overshoot50.npy: [0.7447323318882952]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-jsma_theta0.15_gamma0.5.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-jsma_theta0.15_gamma0.5.npy: [0.004940014114326041]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-jsma_theta0.17_gamma0.5.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-jsma_theta0.17_gamma0.5.npy: [0.006250630103841113]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-jsma_theta0.18_gamma0.5.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-jsma_theta0.18_gamma0.5.npy: [0.006149813489263031]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-jsma_theta0.21_gamma0.5.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-jsma_theta0.21_gamma0.5.npy: [0.007460429478778102]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-jsma_theta0.25_gamma0.5.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-jsma_theta0.25_gamma0.5.npy: [0.010686561145276741]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-pgd_eps0.075.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-pgd_eps0.075.npy: [0.008468595624558928]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-pgd_eps0.082.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-pgd_eps0.082.npy: [0.010081661457808247]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-pgd_eps0.09.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-pgd_eps0.09.npy: [0.011694727291057565]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-pgd_eps0.1.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-pgd_eps0.1.npy: [0.014517592499243875]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-pgd_eps0.11.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-pgd_eps0.11.npy: [0.019659239842726082]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-mim_eps0.06.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-mim_eps0.06.npy: [0.006754713176731525]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-mim_eps0.067.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-mim_eps0.067.npy: [0.007157979635043855]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-mim_eps0.075.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-mim_eps0.075.npy: [0.008871862082871258]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-mim_eps0.085.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-mim_eps0.085.npy: [0.012097993749369896]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-mim_eps0.1.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-mim_eps0.1.npy: [0.014215142655509628]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-onepixel_pxCount15.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-onepixel_pxCount15.npy: [0.010384111301542494]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-onepixel_pxCount30.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-onepixel_pxCount30.npy: [0.014013509426353463]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-onepixel_pxCount35.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-onepixel_pxCount35.npy: [0.01512249218671237]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-onepixel_pxCount40.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-onepixel_pxCount40.npy: [0.016231474947071278]
# >>> Running evaluations on [H:\GitHub\project-athena\data\test_AE-mnist-cnn-clean-onepixel_pxCount75.npy]
# >>> Error Rate of test_AE-mnist-cnn-clean-onepixel_pxCount75.npy: [0.033672749269079545]
# >>> Evaluations on all ae_files dumped to [H:\GitHub\project-athena\Task2\results\baseline_ae_evaluation_results.json]
